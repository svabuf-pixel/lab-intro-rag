# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #FF6347;">Self-Guided Lab: Retrieval-Augmented Generation (RAGs)</h1>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZ3FsdzRveTBrenMxM3VnbDMwaTJxN2NnZm50aGFibXk1NzNnY2Q0MCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/LR5ZBwZHv02lmpVoEU/giphy.gif" alt="NLP Gif" style="width: 300px; height: 150px; object-fit: cover; object-position: center;">
# </div>

# %% [markdown]
# <h1 style="color: #FF6347;">Data Storage & Retrieval</h1>

# %% [markdown]
# <h2 style="color: #FF8C00;">PyPDFLoader</h2>
#
# `PyPDFLoader` is a lightweight Python library designed to streamline the process of loading and parsing PDF documents for text processing tasks. It is particularly useful in Retrieval-Augmented Generation workflows where text extraction from PDFs is required.
#
# - **What Does PyPDFLoader Do?**
#   - Extracts text from PDF files, retaining formatting and layout.
#   - Simplifies the preprocessing of document-based datasets.
#   - Supports efficient and scalable loading of large PDF collections.
#
# - **Key Features:**
#   - Compatible with popular NLP libraries and frameworks.
#   - Handles multi-page PDFs and embedded images (e.g., OCR-compatible setups).
#   - Provides flexible configurations for structured text extraction.
#
# - **Use Cases:**
#   - Preparing PDF documents for retrieval-based systems in RAGs.
#   - Automating the text extraction pipeline for document analysis.
#   - Creating datasets from academic papers, technical manuals, and reports.

# %%
# %pip install langchain langchain_community pypdf
# %pip install termcolor langchain_openai langchain-huggingface sentence-transformers chromadb langchain_chroma tiktoken openai python-dotenv
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/4c/87/324ae5fd9993f024339a452fc89e3fd808bccde87ef95c8dafab3de023c0/langchain-1.2.14-py3-none-any.whl.metadata
#   Downloading langchain-1.2.14-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain_community
#   Obtaining dependency information for langchain_community from https://files.pythonhosted.org/packages/f0/a4/c4fde67f193401512337456cabc2148f2c43316e445f5decd9f8806e2992/langchain_community-0.4.1-py3-none-any.whl.metadata
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pypdf
#   Obtaining dependency information for pypdf from https://files.pythonhosted.org/packages/a5/7e/c85f41243086a8fe5d1baeba527cb26a1918158a565932b41e0f7c0b32e9/pypdf-6.9.2-py3-none-any.whl.metadata
#   Downloading pypdf-6.9.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Obtaining dependency information for langchain-core<2.0.0,>=1.2.10 from https://files.pythonhosted.org/packages/3d/0e/7b31b0249f9b9b0fc7829d5b0ee484b8f8d43c78e376e9951e2ef3eac70c/langchain_core-1.2.25-py3-none-any.whl.metadata
#   Downloading langchain_core-1.2.25-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.1 (from langchain)
#   Obtaining dependency information for langgraph<1.2.0,>=1.1.1 from https://files.pythonhosted.org/packages/d0/74/22ea4734247b59e7c98e575e31a1f463366b084e0dc83cf63715b079ff28/langgraph-1.1.4-py3-none-any.whl.metadata
#   Downloading langgraph-1.1.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Obtaining dependency information for pydantic<3.0.0,>=2.7.4 from https://files.pythonhosted.org/packages/5a/87/b70ad306ebb6f9b585f114d0ac2137d792b48be34d732d60e597c2f8465a/pydantic-2.12.5-py3-none-any.whl.metadata
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ------------- -------------------------- 30.7/90.6 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 90.6/90.6 kB 1.3 MB/s eta 0:00:00
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Obtaining dependency information for langchain-classic<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/ab/e6/cfdeedec0537ffbf5041773590d25beb7f2aa467cc6630e788c9c7c72c3e/langchain_classic-1.0.3-py3-none-any.whl.metadata
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Obtaining dependency information for SQLAlchemy<3.0.0,>=1.4.0 from https://files.pythonhosted.org/packages/f2/af/c3c7e1f3a2b383155a16454df62ae8c62a30dd238e42e68c24cebebbfae6/sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl.metadata
#   Downloading sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in e:\python\.venv_gpu\lib\site-packages (from langchain_community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in e:\python\.venv_gpu\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\python\.venv_gpu\lib\site-packages (from langchain_community) (3.13.4)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_community)
#   Obtaining dependency information for tenacity!=8.4.0,<10.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/d7/c1/eb8f9debc45d3b7918a32ab756658a0904732f75e555402972246b0b8e71/tenacity-9.1.4-py3-none-any.whl.metadata
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Obtaining dependency information for dataclasses-json<0.7.0,>=0.6.7 from https://files.pythonhosted.org/packages/c3/be/d0d44e092656fe7a06b55e6103cbce807cdbdee17884a5367c68c9860853/dataclasses_json-0.6.7-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Obtaining dependency information for pydantic-settings<3.0.0,>=2.10.1 from https://files.pythonhosted.org/packages/00/4b/ccc026168948fec4f7555b9164c724cf4125eac006e176541483d2c959be/pydantic_settings-2.13.1-py3-none-any.whl.metadata
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain_community)
#   Obtaining dependency information for langsmith<1.0.0,>=0.1.125 from https://files.pythonhosted.org/packages/29/13/67889d41baf7dbaf13ffd0b334a0f284e107fad1cc8782a1abb1e56e5eeb/langsmith-0.7.25-py3-none-any.whl.metadata
#   Downloading langsmith-0.7.25-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Obtaining dependency information for httpx-sse<1.0.0,>=0.4.0 from https://files.pythonhosted.org/packages/d2/fd/6668e5aec43ab844de6fc74927e155a3b37bf40d7c3790e49fc0406b6578/httpx_sse-0.4.3-py3-none-any.whl.metadata
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in e:\python\.venv_gpu\lib\site-packages (from langchain_community) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\python\.venv_gpu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.23.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/be/2f/5108cb3ee4ba6501748c4908b908e55f42a5b66245b4cfe0c99326e1ef6e/marshmallow-3.26.2-py3-none-any.whl.metadata
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Obtaining dependency information for langchain-text-splitters<2.0.0,>=1.1.1 from https://files.pythonhosted.org/packages/84/66/d9e0c3b83b0ad75ee746c51ba347cacecb8d656b96e1d513f3e334d1ccab/langchain_text_splitters-1.1.1-py3-none-any.whl.metadata
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Obtaining dependency information for jsonpatch<2.0.0,>=1.33.0 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2.0 in e:\python\.venv_gpu\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\python\.venv_gpu\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Obtaining dependency information for uuid-utils<1.0,>=0.12.0 from https://files.pythonhosted.org/packages/83/92/2d7e90df8b1a69ec4cff33243ce02b7a62f926ef9e2f0eca5a026889cd73/uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Obtaining dependency information for langgraph-checkpoint<5.0.0,>=2.1.0 from https://files.pythonhosted.org/packages/65/4c/09a4a0c42f5d2fc38d6c4d67884788eff7fd2cfdf367fdf7033de908b4c0/langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Obtaining dependency information for langgraph-prebuilt<1.1.0,>=1.0.8 from https://files.pythonhosted.org/packages/dc/41/ec966424ad3f2ed3996d24079d3342c8cd6c0bd0653c12b2a917a685ec6c/langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata
#   Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Obtaining dependency information for langgraph-sdk<0.4.0,>=0.3.0 from https://files.pythonhosted.org/packages/17/4d/4f796e86b03878ab20d9b30aaed1ad459eda71a5c5b67f7cfe712f3548f2/langgraph_sdk-0.3.12-py3-none-any.whl.metadata
#   Downloading langgraph_sdk-0.3.12-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in e:\python\.venv_gpu\lib\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\python\.venv_gpu\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Obtaining dependency information for orjson>=3.9.14 from https://files.pythonhosted.org/packages/ed/9a/9796f8fbe3cf30ce9cb696748dbb535e5c87be4bf4fe2e9ca498ef1fa8cf/orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata
#   Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB ? eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Obtaining dependency information for requests-toolbelt>=1.0.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.1.125->langchain_community)
#   Obtaining dependency information for zstandard>=0.23.0 from https://files.pythonhosted.org/packages/79/3b/fa54d9015f945330510cb5d0b0501e8253c127cca7ebe8ba46a965df18c5/zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Obtaining dependency information for pydantic-core==2.41.5 from https://files.pythonhosted.org/packages/86/45/00173a033c801cacf67c190fef088789394feaf88a98a7035b0e40d53dc9/pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Obtaining dependency information for typing-inspection>=0.4.2 from https://files.pythonhosted.org/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Obtaining dependency information for python-dotenv>=0.21.0 from https://files.pythonhosted.org/packages/0b/d7/1959b9648791274998a9c3526f6d0ec8fd2233e4d4acce81bbae76b44b2a/python_dotenv-1.2.2-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\python\.venv_gpu\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\.venv_gpu\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\python\.venv_gpu\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in e:\python\.venv_gpu\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.2.25)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/9b/40/cc802e067d02af8b60b6771cea7d57e21ef5e6659912814babb42b864713/greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in e:\python\.venv_gpu\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in e:\python\.venv_gpu\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\python\.venv_gpu\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain)
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/9e/6a/a83720e953b1682d2d109d3c2dbb0bc9bf28cc1cbc205be4ef4be5da709d/jsonpointer-3.1.1-py3-none-any.whl.metadata
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain)
#   Obtaining dependency information for ormsgpack>=1.12.0 from https://files.pythonhosted.org/packages/7a/0c/9803aa883d18c7ef197213cd2cbf73ba76472a11fe100fb7dab2884edf48/ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Obtaining dependency information for mypy-extensions>=0.3.0 from https://files.pythonhosted.org/packages/79/7b/2c79738432f5c924bef5071f933bcc9efd0473bac3b4aa584a6f7c1c8df8/mypy_extensions-1.1.0-py3-none-any.whl.metadata
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-1.2.14-py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.7 kB ? eta -:--:--
#    ---------------------------------------- 112.7/112.7 kB 6.4 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.5 MB 7.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.5 MB 8.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.9/2.5 MB 10.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.5 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 10.8 MB/s eta 0:00:00
# Downloading pypdf-6.9.2-py3-none-any.whl (333 kB)
#    ---------------------------------------- 0.0/333.7 kB ? eta -:--:--
#    --------------------------------------- 333.7/333.7 kB 20.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ----------------------------- ---------- 0.8/1.0 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 22.4 MB/s eta 0:00:00
# Downloading langchain_core-1.2.25-py3-none-any.whl (506 kB)
#    ---------------------------------------- 0.0/506.9 kB ? eta -:--:--
#    --------------------------------------  501.8/506.9 kB 15.9 MB/s eta 0:00:01
#    --------------------------------------  501.8/506.9 kB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 506.9/506.9 kB 5.3 MB/s eta 0:00:00
# Downloading langgraph-1.1.4-py3-none-any.whl (168 kB)
#    ---------------------------------------- 0.0/168.2 kB ? eta -:--:--
#    ---------------------------------------- 168.2/168.2 kB 9.9 MB/s eta 0:00:00
# Downloading langsmith-0.7.25-py3-none-any.whl (359 kB)
#    ---------------------------------------- 0.0/359.4 kB ? eta -:--:--
#    --------------------------------------- 359.4/359.4 kB 21.8 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.6 kB ? eta -:--:--
#    --------------------------------------- 463.6/463.6 kB 14.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------- ------------------------- 0.7/2.0 MB 23.1 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.0 MB 21.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 9.2 MB/s eta 0:00:00
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.9 kB ? eta -:--:--
#    ---------------------------------------- 58.9/58.9 kB 3.2 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.1 MB 18.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.1 MB 18.5 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 15.2 MB/s eta 0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl (231 kB)
#    ---------------------------------------- 0.0/231.1 kB ? eta -:--:--
#    ----------------------------------- ---- 204.8/231.1 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 231.1/231.1 kB 4.7 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB ? eta 0:00:00
# Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.12-py3-none-any.whl (95 kB)
#    ---------------------------------------- 0.0/95.8 kB ? eta -:--:--
#    ---------------------------------------- 95.8/95.8 kB ? eta 0:00:00
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/51.0 kB ? eta -:--:--
#    ---------------------------------------- 51.0/51.0 kB ? eta 0:00:00
# Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl (127 kB)
#    ---------------------------------------- 0.0/127.4 kB ? eta -:--:--
#    ---------------------------------------- 127.4/127.4 kB 7.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.1 kB ? eta -:--:--
#    --------------------------------------- 187.1/187.1 kB 11.1 MB/s eta 0:00:00
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.3 kB ? eta -:--:--
#    --------------------------------------- 506.3/506.3 kB 31.0 MB/s eta 0:00:00
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
#    ---------------------------------------- 0.0/117.5 kB ? eta -:--:--
#    ---------------------------------------- 117.5/117.5 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: zstandard, uuid-utils, typing-inspection, tenacity, python-dotenv, pypdf, pydantic-core, ormsgpack, orjson, mypy-extensions, marshmallow, jsonpointer, httpx-sse, greenlet, annotated-types, typing-inspect, SQLAlchemy, requests-toolbelt, pydantic, jsonpatch, pydantic-settings, langsmith, langgraph-sdk, dataclasses-json, langchain-core, langgraph-checkpoint, langchain-text-splitters, langgraph-prebuilt, langchain-classic, langgraph, langchain_community, langchain
# Successfully installed SQLAlchemy-2.0.48 annotated-types-0.7.0 dataclasses-json-0.6.7 greenlet-3.3.2 httpx-sse-0.4.3 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.2.14 langchain-classic-1.0.3 langchain-core-1.2.25 langchain-text-splitters-1.1.1 langchain_community-0.4.1 langgraph-1.1.4 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.12 langsmith-0.7.25 marshmallow-3.26.2 mypy-extensions-1.1.0 orjson-3.11.8 ormsgpack-1.12.2 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.13.1 pypdf-6.9.2 python-dotenv-1.2.2 requests-toolbelt-1.0.0 tenacity-9.1.4 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.14.1 zstandard-0.25.0
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# <h3 style="color: #FF8C00;">Loading the Documents</h3>

# %%
# File path for the document
file_path = "../ai-for-everyone.pdf"

# %% [markdown]
# <h3 style="color: #FF8C00;">Documents into pages</h3>
#
# The `PyPDFLoader` library allows efficient loading and splitting of PDF documents into smaller, manageable parts for NLP tasks.
#
# This functionality is particularly useful in workflows requiring granular text processing, such as Retrieval-Augmented Generation (RAG).

# %%
# Load and split the document
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
len(pages)

# %% [markdown]
# <h3 style="color: #FF8C00;">Pages into Chunks</h3>
#
#
# ####  RecursiveCharacterTextSplitter in LangChain
#
# The `RecursiveCharacterTextSplitter` is the **recommended splitter** in LangChain when you want to break down long documents into smaller, semantically meaningful chunks — especially useful in **RAG pipelines**, where clean context chunks lead to better LLM responses.
#
# ####  Parameters
#
# | Parameter       | Description                                                                 |
# |-----------------|-----------------------------------------------------------------------------|
# | `chunk_size`    | The **maximum number of characters** allowed in a chunk (e.g., `1000`).     |
# | `chunk_overlap` | The number of **overlapping characters** between consecutive chunks (e.g., `200`). This helps preserve context continuity. |
#
# ####  How it works
# `RecursiveCharacterTextSplitter` attempts to split the text **intelligently**, trying the following separators in order:
# 1. Paragraphs (`"\n\n"`)
# 2. Lines (`"\n"`)
# 3. Sentences or words (`" "`)
# 4. Individual characters (as a last resort)
#
# This makes it ideal for handling **natural language documents**, such as PDFs, articles, or long reports, without breaking sentences or paragraphs in awkward ways.

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(pages)

len(chunks)

# %% [markdown]
# ####  Alternative: CharacterTextSplitter
#
# `CharacterTextSplitter` is a simpler splitter that breaks text into chunks based **purely on character count**, without trying to preserve any natural language structure.
#
# ##### Example:
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# text_splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
# ````
#
# This method is faster and more predictable but may split text in the middle of a sentence or paragraph, which can hurt performance in downstream tasks like retrieval or QA.
#
# ---
#
# #### Comparison Table
#
# | Feature                        | RecursiveCharacterTextSplitter | CharacterTextSplitter     |
# | ------------------------------ | ------------------------------ | ------------------------- |
# | Structure-aware splitting      |  Yes                          |  No                      |
# | Preserves sentence/paragraphs  |  Yes                          |  No                      |
# | Risk of splitting mid-sentence |  Minimal                     |  High                   |
# | Ideal for RAG/document QA      |  Highly recommended           |  Only if structured text |
# | Performance speed              |  Slightly slower             |  Faster                  |
#
# ---
#
# #### Recommendation
#
# Use `RecursiveCharacterTextSplitter` for most real-world document processing tasks, especially when building RAG pipelines or working with structured natural language content like PDFs or articles.

# %% [markdown]
# ## Best Practices for Choosing Chunk Size in RAG
#
# ### Best Practices for Chunk Size in RAG
#
# | Factor                      | Recommendation                                                                                                                                                                                          |
# | ---------------------------| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **LLM context limit**       | Choose a chunk size that lets you retrieve multiple chunks **without exceeding the model’s token limit**. For example, GPT-4o supports 128k tokens, but with GPT-3.5 (16k) or GPT-4 (32k), keep it modest. |
# | **Chunk size (in characters)** | Typically: **500–1,000 characters** per chunk → ~75–200 tokens. This fits well for retrieval + prompt without context overflow.                                                                           |
# | **Chunk size (in tokens)**  | If using token-based splitter (e.g. `TokenTextSplitter`): aim for **100–300 tokens** per chunk.                                                                                                            |
# | **Chunk overlap**           | Use **overlap of 10–30%** (e.g., 100–300 characters or ~50 tokens) to preserve context across chunk boundaries and avoid cutting off important ideas mid-sentence.                                        |
# | **Document structure**      | Use **`RecursiveCharacterTextSplitter`** to preserve semantic boundaries (paragraphs, sentences) instead of arbitrary cuts.                                                                                |
# | **Task type**               | For **question answering**, smaller chunks (~500–800 chars) reduce noise.<br>For **summarization**, slightly larger chunks (~1000–1500) are OK.                                                          |
# | **Embedding model**         | Some models (e.g., `text-embedding-3-large`) can handle long input. But still, smaller chunks give **finer-grained retrieval**, which improves relevance.                                                  |
# | **Query type**              | If users ask **very specific questions**, small focused chunks are better. For broader queries, bigger chunks might help.                                                                                  |
#
#
# ### Rule of Thumb
#
# | Use Case                 | Chunk Size      | Overlap |
# | ------------------------| --------------- | ------- |
# | Factual Q&A              | 500–800 chars   | 100–200 |
# | Summarization            | 1000–1500 chars | 200–300 |
# | Technical documents      | 400–700 chars   | 100–200 |
# | Long reports/books       | 800–1200 chars  | 200–300 |
# | Small LLMs (≤16k tokens) | ≤800 chars      | 100–200 |
#
#
# ### Avoid
#
# - Chunks >2000 characters: risks context overflow.
# - No overlap: may lose key information between chunks.

# %% [markdown]
# <h2 style="color: #FF8C00;">Embeddings</h2>
#
# Embeddings transform text into dense vector representations, capturing semantic meaning and contextual relationships. They are essential for efficient document retrieval and similarity analysis.
#
# - **What are OpenAI Embeddings?**
#   - Pre-trained embeddings like `text-embedding-3-large` generate high-quality vector representations for text.
#   - Encapsulate semantic relationships in the text, enabling robust NLP applications.
#
# - **Key Features of `text-embedding-3-large`:**
#   - Large-scale embedding model optimized for accuracy and versatility.
#   - Handles diverse NLP tasks, including retrieval, classification, and clustering.
#   - Ideal for applications with high-performance requirements.
#
# - **Benefits:**
#   - Reduces the need for extensive custom training.
#   - Provides state-of-the-art performance in retrieval-augmented systems.
#   - Compatible with RAGs to create powerful context-aware models.

# %%
from langchain.embeddings import OpenAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()

# %%
api_key = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %% [markdown]
# <h2 style="color: #FF8C00;">ChromaDB</h2>
#
# ChromaDB is a versatile vector database designed for efficiently storing and retrieving embeddings. It integrates seamlessly with embedding models to enable high-performance similarity search and context-based retrieval.
#
# ### Workflow Overview:
# - **Step 1:** Generate embeddings using a pre-trained model (e.g., OpenAI's `text-embedding-3-large`).
# - **Step 2:** Store the embeddings in ChromaDB for efficient retrieval and similarity calculations.
# - **Step 3:** Use the stored embeddings to perform searches, matching, or context-based retrieval.
#
# ### Key Features of ChromaDB:
# - **Scalability:** Handles large-scale datasets with optimized indexing and search capabilities.
# - **Speed:** Provides fast and accurate retrieval of embeddings for real-time applications.
# - **Integration:** Supports integration with popular frameworks and libraries for embedding generation.

# %%
from langchain.vectorstores import Chroma

# %%
db = Chroma.from_documents(chunks, embeddings, persist_directory="./chroma_db_LAB")
print("ChromaDB created with document embeddings.")

# %% [markdown]
# <h1 style="color: #FF6347;">Retrieving Documents</h1>

# %% [markdown]
# ### Exercice1: Write a user question that someone might ask about your book’s topic or content.

# %%
user_question = "What is AI and how can companies use machine learning to create business value?"
retrieved_docs = db.similarity_search(
    user_question, k=10
)  # k is the number of documents to retrieve

# %%
# Display top results
for i, doc in enumerate(retrieved_docs[:3]):  # Display top 3 results
    print(f"Document {i+1}:\n{doc.page_content[36:1000]}")  # Display content

# %% [markdown]
# <h2 style="color: #FF8C00;">Preparing Content for GenAI</h2>

# %%
def _get_document_prompt(docs):
    prompt = "\n"
    for doc in docs:
        prompt += "\nContent:\n"
        prompt += doc.page_content + "\n\n"
    return prompt

# %%
# Generate a formatted context from the retrieved documents
formatted_context = _get_document_prompt(retrieved_docs)
print("Context formatted for GPT model.")

# %% [markdown]
# <h2 style="color: #FF8C00;">ChatBot Architecture</h2>

# %% [markdown]
# ### Exercice2: Write a prompt that is relevant and tailored to the content and style of your book.

# %%
prompt = f"""You are a knowledgeable AI assistant helping users understand concepts from the book "AI for Everyone" by Andrew Ng.

Use the following excerpts from the book to answer the user's question clearly and concisely.
Explain concepts in simple, accessible language suitable for a non-technical business professional.
If the answer is not found in the context, say so honestly.

Context:
{formatted_context}

Question: {user_question}

Answer in a clear, friendly, and educational tone.
"""

# %%
import openai

# %% [markdown]
# ### Exercice3: Tune parameters like temperature, and penalties to control how creative, focused, or varied the model's responses are.

# %%
# Set up GPT client and parameters
client = openai.OpenAI()
model_params = {
    "model": "gpt-4o",
    "temperature": 0.7,  # Balanced creativity — not too random, not too rigid
    "max_tokens": 600,  # Allow for detailed but concise responses
    "top_p": 0.9,  # Use nucleus sampling for natural output
    "frequency_penalty": 0.3,  # Reduce repetition of the same phrases
    "presence_penalty": 0.2,  # Mildly encourage introducing new topics
}

# %% [markdown]
# <h1 style="color: #FF6347;">Response</h1>

# %%
messages = [{"role": "user", "content": prompt}]
completion = client.chat.completions.create(messages=messages, **model_params, timeout=120)

# %%
answer = completion.choices[0].message.content
print(answer)

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:824/1*GK56xmDIWtNQAD_jnBIt2g.png" alt="NLP Gif" style="width: 500px">

# %% [markdown]
# <h2 style="color: #FF6347;">Cosine Similarity</h2>
#
# **Cosine similarity** is a metric used to measure the alignment or similarity between two vectors, calculated as the cosine of the angle between them. It is the **most common metric used in RAG pipelines** for vector retrieval.. It provides a scale from -1 to 1:
#
# - **-1**: Vectors are completely opposite.
# - **0**: Vectors are orthogonal (uncorrelated or unrelated).
# - **1**: Vectors are identical.

# %% [markdown]
# <img src="https://storage.googleapis.com/lds-media/images/cosine-similarity-vectors.original.jpg" alt="NLP Gif" style="width: 700px">

# %% [markdown]
# <h2 style="color: #FF6347;">Keyword Highlighting</h2>
#
# Highlighting important keywords helps users quickly understand the relevance of the retrieved text to their query.

# %%
from termcolor import colored

# %% [markdown]
# The `highlight_keywords` function is designed to highlight specific keywords within a given text. It replaces each keyword in the text with a highlighted version using the `colored` function from the `termcolor` library.

# %%
def highlight_keywords(text, keywords):
    for keyword in keywords:
        text = text.replace(keyword, colored(keyword, "green", attrs=["bold"]))
    return text

# %% [markdown]
# ### Exercice4: add your keywords

# %%
query_keywords = [
    "AI",
    "machine learning",
    "data",
    "neural network",
    "business",
    "company",
    "value",
]
for i, doc in enumerate(retrieved_docs[:1]):
    snippet = doc.page_content[:200]
    highlighted = highlight_keywords(snippet, query_keywords)
    print(f"Snippet {i+1}:\n{highlighted}\n{'-'*80}")

# %% [markdown]
# 1. `query_keywords` is a list of keywords to be highlighted.
# 2. The loop iterates over the first document in retrieved_docs.
# 3. For each document, a snippet of the first 200 characters is extracted.
# 4. The highlight_keywords function is called to highlight the keywords in the snippet.
# 5. The highlighted snippet is printed along with a separator line.

# %% [markdown]
# <h1 style="color: #FF6347;">Bonus</h1>

# %% [markdown]
# **Try loading one of your own PDF books and go through the steps again to explore how the pipeline works with your content**:
